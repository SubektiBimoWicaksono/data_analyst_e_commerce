# %% [markdown]
# # Data Analysis Project: [E-Commerce Public Dataset]
# - **Name:** [Subekti Bimo Wicaksono]
# - **Email:** [subektibimowicaksono@student.uns.ac.id]
# - **ID Dicoding:** [subekti_bimo]

# %% [markdown]
# ## Define business question

# %% [markdown]
# - **Questions 1 :** What are the products that shoppers buy most often and the products that shoppers are least interested in?
#
# - **Questions 2 :** What months experience the highest level of sales/transaction activity on e-commerce platforms?

# %% [markdown]
# ## Import the libraries needed for this project.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### customers dataset

# %%
customers = pd.read_csv("https://raw.githubusercontent.com/SubektiBimoWicaksono/E-commerce-public-dataset/main/customers_dataset.csv")
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %% [markdown]
# #### orders dataset

# %%
orders = pd.read_csv("https://raw.githubusercontent.com/SubektiBimoWicaksono/E-commerce-public-dataset/main/orders_dataset.csv")
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %% [markdown]
# #### products dataset

# %%
products = pd.read_csv("https://raw.githubusercontent.com/SubektiBimoWicaksono/E-commerce-public-dataset/main/products_dataset.csv")
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %% [markdown]
# #### sellers dataset

# %%
sellers = pd.read_csv("https://raw.githubusercontent.com/SubektiBimoWicaksono/E-commerce-public-dataset/main/sellers_dataset.csv")
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
sellers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %% [markdown]
# #### geolocation dataset

# %%
geolocation = pd.read_csv("https://raw.githubusercontent.com/SubektiBimoWicaksono/E-commerce-public-dataset/main/geolocation_dataset.csv")
geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
geolocation
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000155                        99965       -28.180655       -52.034367
# 1000156                        99950       -28.072188       -52.011272
# 1000157                        99950       -28.068864       -52.012964
# 1000158                        99950       -28.068639       -52.010705
# 1000161                        99980       -28.388932       -51.846871
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %% [markdown]
# #### items dataset

# %%
items = pd.read_csv("https://raw.githubusercontent.com/SubektiBimoWicaksono/E-commerce-public-dataset/main/order_items_dataset.csv")
items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %% [markdown]
# #### payments dataset

# %%
payments = pd.read_csv("https://raw.githubusercontent.com/SubektiBimoWicaksono/E-commerce-public-dataset/main/order_payments_dataset.csv")
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %% [markdown]
# #### reviews dataset

# %%
reviews = pd.read_csv("https://raw.githubusercontent.com/SubektiBimoWicaksono/E-commerce-public-dataset/main/order_reviews_dataset.csv")
reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# 0                 4
# ...

# %% [markdown]
# #### category dataset

# %%
category = pd.read_csv("https://raw.githubusercontent.com/SubektiBimoWicaksono/E-commerce-public-dataset/main/product_category_name_translation.csv")
category.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
category
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Check Missing Values

# %%
items.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
payments.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
customers.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
geolocation.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
sellers.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
category.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
reviews.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %% [markdown]
# The 'reviews' dataframe has no missing values in the 'review_id', 'order_id', 'review_score', 'review_creation_date', and 'review_answer_timestamp' columns. However, 'review_comment_title' has 87656 missing values and 'review_comment_message' has 58247 missing values, suggesting many reviews lack titles or messages.

# %%
products.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# There are missing values in several product-related columns, with 610 missing values in most attributes and only 2 missing values each in 'product_weight_g', 'product_length_cm', 'product_height_cm', and 'product_width_cm'.

# %%
orders.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# The check shows that most columns have no missing data except for 'order_approved_at', 'order_delivered_carrier_date', and 'order_delivered_customer_date', which have 160, 1783, and 2965 missing values respectively.

# %%
print("orders dataframe")
orders.info()
print("items dataframe")
items.info()
print("products items")
products.info()
print("payments items")
payments.info()
print("reviews items")
reviews.info()
print("customers items")
customers.info()
print("sellers items")
sellers.info()
print("geolocations items")
geolocation.info()
print("category items")
category.info()
# Out:
# orders dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
# items dataframe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ...

# %%
orders['order_purchase_timestamp'] = pd.to_datetime(orders['order_purchase_timestamp'])
orders['order_approved_at'] = pd.to_datetime(orders['order_approved_at'])
orders['order_delivered_carrier_date'] = pd.to_datetime(orders['order_delivered_carrier_date'])
orders['order_delivered_customer_date'] = pd.to_datetime(orders['order_delivered_customer_date'])
orders['order_estimated_delivery_date'] = pd.to_datetime(orders['order_estimated_delivery_date'])

items['shipping_limit_date'] = pd.to_datetime(items['shipping_limit_date'])

reviews['review_creation_date'] = pd.to_datetime(reviews['review_creation_date'])
reviews['review_answer_timestamp'] = pd.to_datetime(reviews['review_answer_timestamp'])

# %%
orders.info()
items.info()
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ...

# %% [markdown]
# #### Check Duplication

# %%
orders_duplicates_count = orders.duplicated().sum()
print("Count of duplicate rows in orders dataset:", orders_duplicates_count)
# Out:
# Count of duplicate rows in orders dataset: 0

# %%
geolocation_duplicates_count = geolocation.duplicated().sum()
print("Count of duplicate rows in orders dataset:", geolocation_duplicates_count)
# Out:
# Count of duplicate rows in orders dataset: 261831

# %% [markdown]
# In the geolocation dataset, there are 261,831 rows with the same values across all columns. These duplicate rows may suggest repetition or errors in the data

# %%
items_duplicates_count = items.duplicated().sum()
print("Count of duplicate rows in orders dataset:", items_duplicates_count)
# Out:
# Count of duplicate rows in orders dataset: 0

# %%
sellers_duplicates_count = sellers.duplicated().sum()
print("Count of duplicate rows in orders dataset:", sellers_duplicates_count)
# Out:
# Count of duplicate rows in orders dataset: 0

# %%
products_duplicates_count = products.duplicated().sum()
print("Count of duplicate rows in orders dataset:", products_duplicates_count)
# Out:
# Count of duplicate rows in orders dataset: 0

# %%
payments_duplicates_count = payments.duplicated().sum()
print("Count of duplicate rows in orders dataset:", payments_duplicates_count)
# Out:
# Count of duplicate rows in orders dataset: 0

# %%
reviews_duplicates_count = reviews.duplicated().sum()
print("Count of duplicate rows in orders dataset:", reviews_duplicates_count)
# Out:
# Count of duplicate rows in orders dataset: 0

# %%
category_duplicates_count = category.duplicated().sum()
print("Count of duplicate rows in orders dataset:", category_duplicates_count)
# Out:
# Count of duplicate rows in orders dataset: 0

# %%
customers_duplicates_count = customers.duplicated().sum()
print("Count of duplicate rows in orders dataset:", customers_duplicates_count)
# Out:
# Count of duplicate rows in orders dataset: 0

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Orders Dataframe

# %% [markdown]
# ##### Handle Missing value

# %% [markdown]
# Remove the missing value from orders dataframe (with datetime data types) using .fillna()

# %%
print('Order who missing delivery dates : ' + str(orders.order_delivered_customer_date.isnull().sum()))
# Out:
# Order who missing delivery dates : 2965

# %% [markdown]
# Missing data in the specified columns ('order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date') are filled by replacing them with the median value of each respective column. This method helps maintain data integrity and preserves the overall distribution characteristics of the dataset while mitigating the impact of missing values.

# %%
orders['order_approved_at'].fillna(orders['order_approved_at'].median(), inplace=True)
orders['order_delivered_carrier_date'].fillna(orders['order_delivered_carrier_date'].median(), inplace=True)
orders['order_delivered_customer_date'].fillna(orders['order_delivered_customer_date'].median(), inplace=True)
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99441 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   99441 non-null  datetime64[ns]
#  6   order_delivered_customer_date  99441 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
orders.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %%
orders['order_status'].value_counts()
# Out:
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_status, dtype: int64

# %% [markdown]
# #### Products Dataframe

# %% [markdown]
# ##### Handle Missing value

# %%
products['product_weight_g'].fillna(products['product_weight_g'].mean(), inplace=True)
products['product_length_cm'].fillna(products['product_length_cm'].mean(), inplace=True)
products['product_height_cm'].fillna(products['product_height_cm'].mean(), inplace=True)
products['product_width_cm'].fillna(products['product_width_cm'].mean(), inplace=True)

products['product_category_name'].fillna(products['product_category_name'].mode()[0], inplace=True)

products['product_name_lenght'].fillna(0, inplace=True)
products['product_description_lenght'].fillna(0, inplace=True)
products['product_photos_qty'].fillna(0, inplace=True)

# %% [markdown]
#  It employs the fillna() method to replace NaN (missing) values with either the mean (for numerical columns) or the mode (for categorical columns) of each respective column, and fills certain columns representing lengths and quantities with zeros assuming missing values indicate absence of data.

# %%
products.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32951.000000                32951.000000        32951.000000
# mean             47.579527                  757.213104            2.148463
# std              12.071951                  637.745057            1.745732
# min               0.000000                    0.000000            0.000000
# 25%              41.000000                  326.000000            1.000000
# 50%              51.000000                  584.000000            1.000000
# 75%              57.000000                  961.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32951.000000       32951.000000       32951.000000
# mean        2276.472488          30.815078          16.937661
# std         4281.908773          16.913945          13.637140
# ...

# %%
products.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# #### Reviews Dataframe

# %% [markdown]
# ##### Handle Missing value

# %%
reviews['review_comment_title'].fillna('', inplace=True)
reviews['review_comment_message'].fillna('', inplace=True)

# %%
reviews.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
reviews.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %% [markdown]
# #### Golocation Dataframe

# %% [markdown]
# ##### Removing Duplicates Rows

# %%
print("Shape of DataFrame before removing duplicates:", geolocation.shape)
geolocation.drop_duplicates(inplace=True)
print("Shape of DataFrame after removing duplicates:", geolocation.shape)
geolocation.to_csv('cleaned_geolocation_dataset.csv', index=False)
# Out:
# Shape of DataFrame before removing duplicates: (1000163, 5)
# Shape of DataFrame after removing duplicates: (738332, 5)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Orders DataFrame
#
# group the data by the 'order_status' column and then apply aggregation functions such as count() to see the frequency of each order status.

# %%
order_status_counts = orders.groupby('order_status').agg(count=('order_id', 'count'))
order_status_counts
# Out:
#               count
# order_status
# approved          2
# canceled        625
# created           5
# delivered     96478
# invoiced        314
# processing      301
# shipped        1107
# unavailable     609

# %% [markdown]
# calculate the time differences between order-related timestamps like 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', and 'order_delivered_customer_date'

# %%
orders['purchase_to_approval_time'] = orders['order_approved_at'] - orders['order_purchase_timestamp']
orders['approval_to_carrier_time'] = orders['order_delivered_carrier_date'] - orders['order_approved_at']
orders['carrier_to_delivery_time'] = orders['order_delivered_customer_date'] - orders['order_delivered_carrier_date']
orders.sample(5)
# Out:
#                                order_id                       customer_id  \
# 54736  0d5fb8614978748bcfbef448c8a74a17  33a3023585bff9c06044bdcd92c95b4b
# 91586  153021ffa26bc5620848b4ab5c7f74a5  0aeeee00a80369aaa6d220e46d74e055
# 6162   6120dca54b9adfd072f8fd9574161063  5744920f3a64d20c68264c46e5222276
# 46373  9fa3141e41678109d614cc3ee569cb98  6c7f22d419350aa50d3ed422fe852df1
# 80509  6353f1b671ade418ad05f552dc16df4b  9be414fa82e43d3fa9cea3b3cc00eae0
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 54736    delivered      2018-08-06 10:00:44 2018-08-06 10:15:30
# 91586    delivered      2017-06-17 20:49:07 2017-06-17 21:05:11
# 6162     delivered      2017-03-03 10:45:26 2017-03-07 04:10:25
# 46373    delivered      2017-11-26 14:16:15 2017-11-26 14:35:01
# 80509    delivered      2017-11-27 09:08:54 2017-11-28 02:56:44
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 54736          2018-08-07 15:47:00           2018-08-15 21:19:33
# ...

# %%
time_diff = orders.agg({
    'purchase_to_approval_time': ['mean', 'median', 'min', 'max'],
    'approval_to_carrier_time': ['mean', 'median', 'min', 'max'],
    'carrier_to_delivery_time': ['mean', 'median', 'min', 'max']
})
time_diff
# Out:
#        purchase_to_approval_time  approval_to_carrier_time  \
# mean   0 days 10:35:32.179252018 4 days 11:01:22.095805553
# median           0 days 00:20:36           1 days 20:09:55
# min          -272 days +18:05:55       -359 days +03:20:37
# max            471 days 15:54:41         477 days 05:44:18
#
#          carrier_to_delivery_time
# mean    9 days 19:38:04.154659546
# median            7 days 03:47:03
# min    -214 days +04:03:10.500000
# max      479 days 03:15:47.500000

# %% [markdown]
# ### Explore Items DataFrame

# %%
order_item = items['order_item_id'].value_counts()
order_item
# Out:
# 1     98666
# 2      9803
# 3      2287
# 4       965
# 5       460
# 6       256
# 7        58
# 8        36
# 9        28
# 10       25
# 11       17
# 12       13
# 13        8
# 14        7
# 15        5
# 16        3
# 17        3
# 18        3
# 19        3
# 20        3
# 21        1
# Name: order_item_id, dtype: int64

# %%
product_stats = items.groupby('product_id').agg({
    'price': ['mean', 'median', 'min', 'max'],
    'freight_value': ['mean', 'median', 'min', 'max']
})
product_stats
# Out:
#                                    price                          \
#                                     mean  median     min     max
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38  101.65  101.65  101.65  101.65
# 00088930e925c41fd95ebfe695fd2655  129.90  129.90  129.90  129.90
# 0009406fd7479715e4bef61dd91f2462  229.00  229.00  229.00  229.00
# 000b8f95fcb9e0096488278317764d19   58.90   58.90   58.90   58.90
# 000d9be29b5207b54e86aa1b1ac54872  199.00  199.00  199.00  199.00
# ...                                  ...     ...     ...     ...
# fff6177642830a9a94a0f2cba5e476d1  114.99  114.99  109.99  119.99
# fff81cc3158d2725c0655ab9ba0f712c   90.00   90.00   90.00   90.00
# fff9553ac224cec9d15d49f5a263411f   32.00   32.00   32.00   32.00
# fffdb2d0ec8d6a61f0a0a0db3f25b441   33.99   34.99   29.99   34.99
# fffe9eeff12fcbd74a2f2b007dde0c58  249.99  249.99  249.99  249.99
#
#                                  freight_value
# ...

# %%
items['shipping_month'] = items['shipping_limit_date'].dt.month
month = items['shipping_month'].value_counts().sort_index()
month_name = {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June',
               7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'}
month.index = month.index.map(month_name)
month
# Out:
# January       8173
# February      9243
# March        11510
# April        10003
# May          12915
# June         10698
# July         10788
# August       13857
# September     4827
# October       5554
# November      7355
# December      7727
# Name: shipping_month, dtype: int64

# %% [markdown]
# The data indicates varying shipment volumes throughout the year, with peaks observed in March, May, August, and December, while September and October show comparatively lower shipment counts.

# %% [markdown]
# ### Explore Products DataFrame
#
# Group the data by 'product_category_name' and calculate aggregate statistics such as mean, median, minimum, and maximum for numerical columns

# %%
product_category = products.groupby('product_category_name').agg({
    'product_photos_qty': ['mean', 'median', 'min', 'max'],
    'product_weight_g': ['mean', 'median', 'min', 'max'],
    'product_length_cm': ['mean', 'median', 'min', 'max'],
    'product_height_cm': ['mean', 'median', 'min', 'max'],
    'product_width_cm': ['mean', 'median', 'min', 'max']
})
product_category
# Out:
#                           product_photos_qty                    \
#                                         mean median  min   max
# product_category_name
# agro_industria_e_comercio           2.310811    1.0  1.0   8.0
# alimentos                           1.939024    1.0  1.0   7.0
# alimentos_bebidas                   1.894231    1.0  1.0  10.0
# artes                               2.163636    1.0  1.0  10.0
# artes_e_artesanato                  3.000000    3.0  1.0   7.0
# ...                                      ...    ...  ...   ...
# sinalizacao_e_seguranca             2.483871    2.0  1.0   9.0
# tablets_impressao_imagem            3.000000    3.0  1.0   7.0
# telefonia                           2.759259    2.0  1.0  13.0
# telefonia_fixa                      2.991379    3.0  1.0  11.0
# utilidades_domesticas               2.212848    1.0  1.0  13.0
#
#                           product_weight_g                          \
# ...

# %%
product_category_counts = products['product_category_name'].value_counts()
product_category_counts
# Out:
# cama_mesa_banho                  3639
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: product_category_name, Length: 73, dtype: int64

# %% [markdown]
# ### Explore Geolocation DataFrame

# %%
geolocation.sample(5)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 892199                        87030       -23.417528       -51.918543
# 975751                        96030       -31.763543       -52.376326
# 872622                        85200       -24.755087       -51.770404
# 364705                        16920       -20.872555       -51.489381
# 660225                        39402       -16.725929       -43.839445
#
#        geolocation_city geolocation_state
# 892199          maringá                PR
# 975751          pelotas                RS
# 872622          pitanga                PR
# 364705         castilho                SP
# 660225    montes claros                MG

# %%
geolocation_state_stats = geolocation.groupby('geolocation_state').agg({
    'geolocation_zip_code_prefix': ['count', 'nunique']
})
geolocation_state_stats
# Out:
#                   geolocation_zip_code_prefix
#                                         count nunique
# geolocation_state
# AC                                       1039      46
# AL                                       3415     178
# AM                                       1986     144
# AP                                        738      26
# BA                                      27720     992
# CE                                       9541     548
# DF                                       9080     516
# ES                                      12632     315
# GO                                      15601     773
# MA                                       6277     313
# MG                                     101353    1868
# MS                                       8594     242
# MT                                       9374     254
# PA                                       8551     309
# PB                                       4787     324
# ...

# %%
geolocation_zip_prefix_stats = geolocation.groupby('geolocation_zip_code_prefix').agg({
    'geolocation_city': 'nunique'
})
geolocation_zip_prefix_stats
# Out:
#                              geolocation_city
# geolocation_zip_code_prefix
# 1001                                        2
# 1002                                        2
# 1003                                        2
# 1004                                        2
# 1005                                        2
# ...                                       ...
# 99960                                       1
# 99965                                       1
# 99970                                       2
# 99980                                       1
# 99990                                       1
#
# [19015 rows x 1 columns]

# %% [markdown]
# ### Explore Reviews DataFrame

# %%
reviews.sample(5)
# Out:
#                               review_id                          order_id  \
# 64603  11add646b6f7db813519cc630785d759  01380d0df5b7dc8bd13f2266a57bd42c
# 62619  4b6d8173b31fd14c1c4b826973c31568  8b030516b5067d6a711fad2df0bab663
# 66194  e7a4acf46d897569ae52bc65004856e6  d62af11a434a8ee473d29426f6b5ff8d
# 8023   08b5e795bb0c0e40b9ec9fa7db0a14f2  3fabb6abad830a556447ea8e809ae9b1
# 71847  34ef973acf8a9d01cceec8e8d7395e29  9f07fd1359b3011a31560b21a4eb1fc4
#
#        review_score review_comment_title review_comment_message  \
# 64603             5
# 62619             4
# 66194             4
# 8023              5
# 71847             5
#
#       review_creation_date review_answer_timestamp
# 64603           2017-04-22     2017-04-24 21:33:35
# 62619           2018-08-22     2018-08-25 00:07:36
# 66194           2017-09-19     2017-09-22 02:21:40
# 8023            2018-08-22     2018-08-22 21:33:36
# 71847           2018-08-17     2018-08-17 20:20:53

# %%
review_score = reviews.groupby('review_score').agg({
    'review_creation_date': ['count', 'min', 'max'],
    'review_answer_timestamp': ['min', 'max']
})
review_score
# Out:
#              review_creation_date                                 \
#                             count                 min        max
# review_score
# 1                           11424 2016-10-02 00:00:00 2018-08-31
# 2                            3151 2016-10-22 00:00:00 2018-08-31
# 3                            8179 2016-10-19 00:00:00 2018-08-31
# 4                           19142 2016-10-15 00:00:00 2018-08-31
# 5                           57328 2016-10-16 01:00:00 2018-08-31
#
#              review_answer_timestamp
#                                  min                 max
# review_score
# 1                2016-10-07 18:32:28 2018-10-22 03:33:14
# 2                2016-10-22 09:25:13 2018-10-16 17:06:29
# 3                2016-10-22 09:57:02 2018-10-17 15:10:18
# 4                2016-10-16 03:20:17 2018-10-21 23:03:07
# 5                2016-10-16 15:45:11 2018-10-29 12:27:35

# %%
reviews['review_creation_month'] = reviews['review_creation_date'].dt.month

monthly_review_count = reviews.groupby('review_creation_month').size()
monthly_review_count
# Out:
# review_creation_month
# 1      6418
# 2      7514
# 3     10284
# 4      9342
# 5     11168
# 6     10155
# 7      9137
# 8     13490
# 9      4199
# 10     4603
# 11     4887
# 12     8027
# dtype: int64

# %% [markdown]
# ### Explore Customers DataFrame

# %%
customers.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 88531  953bf9515f1c2fa444e76ebdd43fb1a9  46c77557bf7c39b4ab3d1e16323dba9a
# 35527  b93e95e6174fff9b5edcc6b8ffea5402  4d679de4b206350c05fcd2591f162bcb
# 6775   42be08802b14ff1e10bc5bec7f1beae9  2d07c5651faf08b9f6536a2bbf74adce
# 23530  cc57bf7b13c49c59095d09da7a63abfc  28b8333651c1350cc561dfe5678b0902
# 90704  04ab012a558c5d12ae6037840f85a860  4ce627d55383d1d22fb03e7555cbdc50
#
#        customer_zip_code_prefix       customer_city customer_state
# 88531                      4581           sao paulo             SP
# 35527                     12630  cachoeira paulista             SP
# 6775                      21381      rio de janeiro             RJ
# 23530                     38800         sao gotardo             MG
# 90704                      3568           sao paulo             SP

# %%
customers_state_stats = customers.groupby('customer_state').agg({
    'customer_id': ['count', 'nunique'],
    'customer_unique_id': 'nunique'
})
customers_state_stats
# Out:
#                customer_id         customer_unique_id
#                      count nunique            nunique
# customer_state
# AC                      81      81                 77
# AL                     413     413                401
# AM                     148     148                143
# AP                      68      68                 67
# BA                    3380    3380               3277
# CE                    1336    1336               1313
# DF                    2140    2140               2075
# ES                    2033    2033               1964
# GO                    2020    2020               1952
# MA                     747     747                726
# MG                   11635   11635              11259
# MS                     715     715                694
# MT                     907     907                876
# PA                     975     975                949
# PB                     536     536                519
# ...

# %%
zip_prefix_stats = customers.groupby('customer_zip_code_prefix').agg({
    'customer_id': ['count', 'nunique'],
    'customer_unique_id': 'nunique'
})
zip_prefix_stats
# Out:
#                          customer_id         customer_unique_id
#                                count nunique            nunique
# customer_zip_code_prefix
# 1003                               1       1                  1
# 1004                               2       2                  2
# 1005                               6       6                  5
# 1006                               2       2                  2
# 1007                               4       4                  4
# ...                              ...     ...                ...
# 99960                              2       2                  2
# 99965                              2       2                  2
# 99970                              1       1                  1
# 99980                              2       2                  2
# 99990                              1       1                  1
#
# [14994 rows x 3 columns]

# %% [markdown]
# ### Explore Payments DataFrame

# %%
payments.sample(5)
# Out:
#                                order_id  payment_sequential payment_type  \
# 47336  a04875dac0e5be70a331df6f1abda67e                   1  credit_card
# 63614  d396cdbf2645bb1ea08108de01ef308a                   1  credit_card
# 64253  a642cf2d3b520954533d3fba8ffc6f72                   1  credit_card
# 7208   5d8614cc1b5fa0f33976b87215bbdb0c                   1  credit_card
# 29952  d6de1a325f87726ee52e1ffe80c35a1a                   1       boleto
#
#        payment_installments  payment_value
# 47336                     1          99.09
# 63614                     3          70.14
# 64253                     1         110.32
# 7208                     14         417.45
# 29952                     1          45.13

# %%
payment_type = payments.groupby('payment_type').agg({
    'payment_installments': ['count', 'mean', 'median', 'min', 'max'],
    'payment_value': ['mean', 'median', 'min', 'max']
})
payment_type
# Out:
#              payment_installments                          payment_value  \
#                             count      mean median min max          mean
# payment_type
# boleto                      19784  1.000000    1.0   1   1    145.034435
# credit_card                 76795  3.507155    3.0   0  24    163.319021
# debit_card                   1529  1.000000    1.0   1   1    142.570170
# not_defined                     3  1.000000    1.0   1   1      0.000000
# voucher                      5775  1.000000    1.0   1   1     65.703354
#
#
#               median    min       max
# payment_type
# boleto         93.89  11.62   7274.88
# credit_card   106.87   0.01  13664.08
# debit_card     89.30  13.38   4445.50
# not_defined     0.00   0.00      0.00
# voucher        39.28   0.00   3184.34

# %% [markdown]
# ### Explore Category DataFrame

# %%
category.sample(5)
# Out:
#       product_category_name product_category_name_english
# 28  fashion_roupa_masculina         fashion_male_clothing
# 67       artes_e_artesanato         arts_and_craftmanship
# 9        relogios_presentes                 watches_gifts
# 10        alimentos_bebidas                    food_drink
# 19           consoles_games                consoles_games

# %%
unique_categories = category['product_category_name_english'].nunique()

print("Number of unique translated categories:", unique_categories)
# Out:
# Number of unique translated categories: 71

# %% [markdown]
# ### Explore Sellers DataFrame

# %%
sellers.sample(5)
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 1767  0ddefe3c7a032b91f4e25b9c3a08fca1                    9721
# 2720  1025f0e2d44d7041d6cf58b6550e0bfa                    3204
# 2678  bd1d49a326abfa9b1036772e40445430                   17017
# 2148  72431a818f97fe6ab9c81eee3e297e54                   13390
# 748   3faf68a3b0af94b10bac70d86077be49                   13825
#
#                 seller_city seller_state
# 1767  sao bernardo do campo           SP
# 2720              sao paulo           SP
# 2678                  bauru           SP
# 2148         rio das pedras           SP
# 748                holambra           SP

# %%
sellers_state_stats = sellers.groupby('seller_state').agg({
    'seller_id': ['count', 'nunique']
})
sellers_state_stats
# Out:
#              seller_id
#                  count nunique
# seller_state
# AC                   1       1
# AM                   1       1
# BA                  19      19
# CE                  13      13
# DF                  30      30
# ES                  23      23
# GO                  40      40
# MA                   1       1
# MG                 244     244
# MS                   5       5
# MT                   4       4
# PA                   1       1
# PB                   6       6
# PE                   9       9
# PI                   1       1
# PR                 349     349
# RJ                 171     171
# RN                   5       5
# RO                   2       2
# RS                 129     129
# SC                 190     190
# SE                   2       2
# SP                1849    1849

# %% [markdown]
# ### Merge DataSet

# %%
merge_data = pd.merge(items, sellers, on='seller_id', how='left')
merge_data = pd.merge(merge_data, products, on='product_id', how='left')

merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   order_id                    112650 non-null  object
#  1   order_item_id               112650 non-null  int64
#  2   product_id                  112650 non-null  object
#  3   seller_id                   112650 non-null  object
#  4   shipping_limit_date         112650 non-null  datetime64[ns]
#  5   price                       112650 non-null  float64
#  6   freight_value               112650 non-null  float64
#  7   shipping_month              112650 non-null  int64
#  8   seller_zip_code_prefix      112650 non-null  int64
#  9   seller_city                 112650 non-null  object
#  10  seller_state                112650 non-null  object
#  11  product_category_name       112650 non-null  object
# ...

# %% [markdown]
# Values closer to 1 indicate a strong positive correlation, while values closer to -1 indicate a strong negative correlation, and values around 0 suggest little to no linear relationship between the variables.

# %%
correlation_matrix = merge_data.corr()
correlation_matrix
# Out:
# <ipython-input-86-8c4f4e2ba023>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = merge_data.corr()
#                             order_item_id     price  freight_value  \
# order_item_id                    1.000000 -0.060522      -0.029380
# price                           -0.060522  1.000000       0.414204
# freight_value                   -0.029380  0.414204       1.000000
# shipping_month                   0.005582  0.005535       0.007966
# seller_zip_code_prefix          -0.018721  0.086416       0.150204
# product_name_lenght             -0.017261  0.017424       0.029542
# product_description_lenght      -0.013460  0.195319       0.095052
# product_photos_qty              -0.054272  0.051682       0.024674
# product_weight_g                -0.003550  0.338667       0.610410
# ...

# %%
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.boxplot(x='product_category_name', y='product_weight_g', data=merge_data)
plt.title('Distribution of Product Weight by Category')
plt.xlabel('Product Category')
plt.ylabel('Product Weight (g)')
plt.xticks(rotation=45)
plt.show()

# %%
customers_orders = pd.merge(
    left=customers,
    right=orders,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
customers_orders.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# merges the 'customers' and 'orders' dataframes based on the 'customer_id' column, linking customers to their respective orders. The resulting dataframe, 'cust_orders'.

# %%
customers_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 0 to 99440
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_id                    99441 non-null  object
#  1   customer_unique_id             99441 non-null  object
#  2   customer_zip_code_prefix       99441 non-null  int64
#  3   customer_city                  99441 non-null  object
#  4   customer_state                 99441 non-null  object
#  5   order_id                       99441 non-null  object
#  6   order_status                   99441 non-null  object
#  7   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  8   order_approved_at              99441 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   99441 non-null  datetime64[ns]
#  10  order_delivered_customer_date  99441 non-null  datetime64[ns]
# ...

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   order_id                    112650 non-null  object
#  1   order_item_id               112650 non-null  int64
#  2   product_id                  112650 non-null  object
#  3   seller_id                   112650 non-null  object
#  4   shipping_limit_date         112650 non-null  datetime64[ns]
#  5   price                       112650 non-null  float64
#  6   freight_value               112650 non-null  float64
#  7   shipping_month              112650 non-null  int64
#  8   seller_zip_code_prefix      112650 non-null  int64
#  9   seller_city                 112650 non-null  object
#  10  seller_state                112650 non-null  object
#  11  product_category_name       112650 non-null  object
# ...

# %%
customers_orders.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False)
customers_orders.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 10274  ba57463d587cb70d3871b2ebc91c6284  5e8f38a9a1c023f3db718edcf926a2db
# 37717  5c4dc29c67a87f143cea0b5df952d169  eb307efee7c5852903169b7506edaceb
# 95178  dbcdae75dc4490db8007ce62565d512c  bb3d6a451634de7b6d913793e4f7520c
# 30456  e341b3f8d88fc48a56221bacbe1d7e55  29cae4eac830b7c65e5250dc9ee77ea6
# 23393  e5935642ca2560fa7b1591c18d6876ec  859e3cbfe63e855467fb316b30267188
#
#        customer_zip_code_prefix     customer_city customer_state  \
# 10274                     44053  feira de santana             BA
# 37717                      1232         sao paulo             SP
# 95178                     25911              mage             RJ
# 30456                     13974           itapira             SP
# 23393                     72660          brasilia             DF
#
#                                order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# merges the 'payments' and 'reviews' dataframes based on the common 'order_id' column, linking payment information with corresponding reviews for orders. The resulting dataframe, 'payment_review'.

# %%
payment_review = pd.merge(
    left=payments,
    right=reviews,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
payment_review.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score review_comment_title  \
# 0           1.0        Não recomendo
# 1           5.0
# ...

# %% [markdown]
# ### Merge All Data
#
# This will merge the two dataframes based on the 'order_id' column, combining the information from both dataframes into a single dataframe based on matching order IDs.

# %%
all_dataset = pd.merge(
    left=customers_orders,
    right=merge_data,
    how="inner",
    on="order_id"
)
all_dataset
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2       4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3       b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4       4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                  ...                               ...
# 112645  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 112646  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 112647  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 112648  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 112649  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
# ...

# %%
final_dataset = pd.merge(
    left=payment_review,
    right=all_dataset,
    how="right",
    on="order_id"
)
final_dataset
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       00e7ee1b050b8499577073aeb2a297a1                 1.0  credit_card
# 1       29150127e6685892b6eab3eec79f59c7                 1.0  credit_card
# 2       b2059ed67ce144a36e2aa97d2c9e9ad2                 1.0  credit_card
# 3       951670f92359f4fe4a63112aa7306eba                 1.0  credit_card
# 4       6b7d50bd145f6fc7f33cebabd7e49d0f                 1.0  credit_card
# ...                                  ...                 ...          ...
# 118305  6760e20addcf0121e9d58f2f1ff14298                 1.0  credit_card
# 118306  9ec0c8947d973db4f4e8dcf1fbfa8f1b                 1.0  credit_card
# 118307  fed4434add09a6f332ea398efd656a5c                 1.0  credit_card
# 118308  e31ec91cea1ecf97797787471f98a8c2                 1.0  credit_card
# 118309  28db69209a75e59f20ccbb5c36a20b90                 1.0  credit_card
#
#         payment_installments  payment_value                         review_id  \
# ...

# %%
final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118310 entries, 0 to 118309
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118310 non-null  object
#  1   payment_sequential             118307 non-null  float64
#  2   payment_type                   118307 non-null  object
#  3   payment_installments           118307 non-null  float64
#  4   payment_value                  118307 non-null  float64
#  5   review_id                      117329 non-null  object
#  6   review_score                   117329 non-null  float64
#  7   review_comment_title           117329 non-null  object
#  8   review_comment_message         117329 non-null  object
#  9   review_creation_date           117329 non-null  datetime64[ns]
#  10  review_answer_timestamp        117329 non-null  datetime64[ns]
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Question 1:
# What are the products that shoppers buy most often and the products that shoppers are least interested in?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
top_products = final_dataset['product_category_name'].value_counts().head(20)
sns.barplot(x=top_products.values, y=top_products.index, palette='cividis')
plt.title('Top 20 Best Selling Products')
plt.xlabel('Number of Sales')
plt.ylabel('Product Category')
plt.show()
# Out:
# <ipython-input-108-e47a310747e1>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_products.values, y=top_products.index, palette='cividis')  # Mengubah palet warna menjadi 'cividis'

# %% [markdown]
# ### Question 2:
#
# What months experience the highest level of sales/transaction activity on e-commerce platforms?

# %%
import matplotlib.pyplot as plt

months = month.index
counts = month.values

plt.figure(figsize=(10, 6))
plt.bar(months, counts, color='pink')
plt.title('Transactional Activity by Month')
plt.xlabel('Month')
plt.ylabel('Number Transactions')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# ### Eksport Finall DataSet To CSV

# %%
final_dataset.to_csv("DataSet_All.csv", index=False)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - **Conclusion 1 :** Based on the data I analyzed, August was the month with the highest level of sales/transaction activity on the e-commerce platform.
# - **Conclusion 2 :** The most frequently purchased products by buyers were products in the "cama_mesa_banho" category while the least popular products by buyers or the least sold were "beleza_saude" products.
